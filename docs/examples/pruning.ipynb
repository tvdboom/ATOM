# %% [markdown]
# # Example: Pruning
# ------------------
#
# This example shows an advanced example on how to optimize your model's hyperparameters for multi-metric runs.
#
# Import the breast cancer dataset from [sklearn.datasets](https://scikit-learn.org/stable/datasets/index.html#wine-dataset). This is a small and easy to train dataset whose goal is to predict whether a patient has breast cancer or not.

# %% [markdown]
# ## Load the data

# %%
# Import packages
from sklearn.datasets import load_breast_cancer
from optuna.pruners import HyperbandPruner
from atom import ATOMClassifier

# %%
# Load the data
X, y = load_breast_cancer(return_X_y=True)

# %% [markdown]
# ## Run the pipeline

# %%
# Initialize atom
atom = ATOMClassifier(X, y, verbose=2, random_state=1)
# Out:
# << ================== ATOM ================== >>
# Algorithm task: binary classification.
#
# Dataset stats ==================== >>
# Shape: (569, 31)
# Memory: 138.96 kB
# Scaled: False
# Outlier values: 167 (1.2%)
# -------------------------------------
# Train set size: 456
# Test set size: 113
# -------------------------------------
# |   |     dataset |       train |        test |
# | - | ----------- | ----------- | ----------- |
# | 0 |   212 (1.0) |   170 (1.0) |    42 (1.0) |
# | 1 |   357 (1.7) |   286 (1.7) |    71 (1.7) |

# %%
# Use ht_params to specify a custom pruner
# Note that pruned trials show the number of iterations it completed
atom.run(
    models="SGD",
    metric="f1",
    n_trials=25,
    ht_params={
        "distributions": ["penalty", "max_iter"],
        "pruner": HyperbandPruner(),
    }
)
# Out:
# Training ========================= >>
# Models: SGD
# Metric: f1
#
#
# Running hyperparameter tuning for StochasticGradientDescent...
# | trial | penalty | max_iter |      f1 | best_f1 | time_trial | time_ht |    state |
# | ----- | ------- | -------- | ------- | ------- | ---------- | ------- | -------- |
# | 0     |      l1 |      650 |  0.9735 |  0.9735 |     1.906s |  1.906s | COMPLETE |
# | 1     | elast.. |     1050 |  0.9739 |  0.9739 |     3.141s |  5.047s | COMPLETE |
# | 2     | elast.. |      500 |  0.9558 |  0.9739 |     1.511s |  6.558s | COMPLETE |
# | 3     |    none |    1/700 |  0.9655 |  0.9739 |     0.015s |  6.573s |   PRUNED |
# | 4     |      l1 |   3/1400 |  0.9821 |  0.9821 |     0.021s |  6.594s |   PRUNED |
# | 5     |    none |   3/1400 |  0.9821 |  0.9821 |     0.021s |  6.615s |   PRUNED |
# | 6     |      l2 |  27/1200 |  0.9825 |  0.9825 |     0.090s |  6.705s |   PRUNED |
# | 7     |      l2 |   3/1250 |  0.9735 |  0.9825 |     0.021s |  6.726s |   PRUNED |
# | 8     |    none |    1/600 |  0.9912 |  0.9912 |     0.016s |  6.742s |   PRUNED |
# | 9     |      l1 |    3/600 |  0.9655 |  0.9912 |     0.024s |  6.766s |   PRUNED |
# | 10    |      l1 |   9/1000 |  0.9735 |  0.9912 |     0.040s |  6.806s |   PRUNED |
# | 11    | elast.. |   1/1200 |   0.955 |  0.9912 |     0.016s |  6.822s |   PRUNED |
# | 12    |      l2 |    1/550 |  0.9541 |  0.9912 |     0.015s |  6.837s |   PRUNED |
# | 13    | elast.. |   1/1100 |  0.9636 |  0.9912 |     0.015s |  6.852s |   PRUNED |
# | 14    | elast.. |    1/900 |  0.9381 |  0.9912 |     0.018s |  6.870s |   PRUNED |
# | 15    |    none |      900 |  0.9636 |  0.9912 |     2.637s |  9.508s | COMPLETE |
# | 16    |      l1 |    1/800 |  0.9474 |  0.9912 |     0.019s |  9.527s |   PRUNED |
# | 17    |      l1 |   27/850 |  0.9821 |  0.9912 |     0.092s |  9.619s |   PRUNED |
# | 18    |      l1 |   1/1500 |  0.8727 |  0.9912 |     0.023s |  9.642s |   PRUNED |
# | 19    | elast.. |      500 |  0.9558 |  0.9912 |     0.004s |  9.646s | COMPLETE |
# | 20    |      l1 |   3/1250 |  0.9483 |  0.9912 |     0.021s |  9.667s |   PRUNED |
# | 21    |    none |      750 |  0.9825 |  0.9912 |     2.200s | 11.867s | COMPLETE |
# | 22    |      l2 |   3/1150 |  0.9735 |  0.9912 |     0.022s | 11.889s |   PRUNED |
# | 23    |      l1 |   1/1000 |  0.9735 |  0.9912 |     0.019s | 11.908s |   PRUNED |
# | 24    |      l1 |    3/900 |  0.9739 |  0.9912 |     0.021s | 11.929s |   PRUNED |
# Hyperparameter tuning ---------------------------
# Best trial --> 21
# Best parameters:
#  --> penalty: none
#  --> max_iter: 750
# Best evaluation --> f1: 0.9825
# Time elapsed: 11.929s
# Results for StochasticGradientDescent:
# Fit ---------------------------------------------
# Train evaluation --> f1: 0.9965
# Test evaluation --> f1: 0.9353
# Time elapsed: 3.343s
# -------------------------------------------------
# Total time: 15.272s
#
#
# Final results ==================== >>
# Total time: 15.324s
# -------------------------------------
# StochasticGradientDescent --> f1: 0.9353

# %% [markdown]
# ## Analyze the results

# %%
atom.plot_trials()
